# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# __SQL databases contain tables where each row has the same keys and the tables in the database have relationships.  NoSQL databases are those that are not SQL and use different types of structures to house data._____________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# __A situation where NoSQL would be better would be a database of twitter users and their followed/follower accounts, which would be more appropriate for a Graph Database._____________________________________________________________________________________________________________________________
#
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# __MongoDB is a document store, where each item is a document that can contain documents within.  Each document does not need to contain the same keys, unlike a relational database._____________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# _____Fault tolerance is the ability to overcome a fault in the data server.  RDD's have redudancy by storing backups of each block in each other block.  That way, if the block goes down, another block will pick up the processes.__________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# ___MapReduce is sending the same request to each server (map) and then reducing the resul____________________________________________________________________________________________________________________________
#
#
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
